# %% [markdown]
# ## Идеи
#
# ### Попроще
#
# - добавить инфу о компании при выборе тикера на бирже или в портфеле (коэфы, описание и тд)
# - выводить количество денег при попытке купить акции (чел должен видеть, скока у него есть, чтобы понимать, скока купить)
# - "да" и "нет" при покупке изменить на "подтвердить" и "назад" (про "назад" ниже)
# - к каждой акции дописать изменение в цене в процентах и прибыль
# - володин, которому ничего не надо
# - переписать вывод клавиатуры со списком акций на циклический
#
# ### Посложнее
#
# - добавить кнопку "назад" (через колбеки)
# - ввести аналитику портфеля
# - ввести рейтинговую систему
